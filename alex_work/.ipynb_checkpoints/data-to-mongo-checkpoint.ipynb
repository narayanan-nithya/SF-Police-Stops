# %%
import pandas as pd
import requests

# %%
# Import & read CSV file

csv_data = '../test-data-2.csv'


# Create dataframe based on CSV file

data = pd.read_csv(csv_data)

list(data.columns)
# Out:
# ['raw_row_number',
#  'date',
#  'time',
#  'location',
#  'lat',
#  'lng',
#  'district',
#  'subject_age',
#  'subject_race',
#  'subject_sex',
#  'type',
#  'arrest_made',
#  'citation_issued',
#  'warning_issued',
#  'outcome',
#  'contraband_found',
#  'search_conducted',
#  'search_vehicle',
#  'search_basis',
#  'reason_for_stop',
#  'raw_search_vehicle_description',
#  'raw_result_of_contact_description']

# %%
# Remove unwanted columns

df = pd.DataFrame(data)

df = df.drop(columns=['raw_row_number',
                      'location',
                      'district',
                      'type',
                      'citation_issued',
                      'contraband_found',
                      'search_conducted',
                      'search_vehicle',
                      'reason_for_stop',
                      'raw_search_vehicle_description',
                      'raw_result_of_contact_description',
                      'search_basis',
                      ])

df.head()
# Out:
#        date     time        lat         lng  subject_age subject_race  \
# 0  1/1/2015  1:00:00  37.736362 -122.390097           23        black
# 1  1/1/2015  1:00:00  37.742207 -122.422097           30     hispanic
# 2  1/1/2015  1:00:00  37.745603 -122.419898           35        white
# 3  1/1/2015  1:00:00  37.782485 -122.424125           44        white
# 4  1/1/2015  1:00:00  37.742822 -122.481078           60        white
#
#   subject_sex  arrest_made  warning_issued   outcome
# 0        male        False            True   warning
# 1      female        False            True   warning
# 2        male        False           False  citation
# 3        male        False           False  citation
# 4        male        False            True   warning

# %%
# Fill in NA values with unknown values

values = {'date': "1/1/1900", 
          'time': "00:00:00",  
          'subject_age': 0, 
          'subject_race':"other", 
          'subject_sex': "unknown", 
          'arrest_made':"unknown", 
          'warning_issued': "unknown", 
          'outcome': "unknown"}

df1 = df.fillna(value=values)

df1.head(-1)
# Out:
#         date      time        lat         lng  subject_age  \
# 0   1/1/2015   1:00:00  37.736362 -122.390097           23
# 1   1/1/2015   1:00:00  37.742207 -122.422097           30
# 2   1/1/2015   1:00:00  37.745603 -122.419898           35
# 3   1/1/2015   1:00:00  37.782485 -122.424125           44
# 4   1/1/2015   1:00:00  37.742822 -122.481078           60
# ..       ...       ...        ...         ...          ...
# 93  1/1/2015  19:20:00  37.780474 -122.475113           21
# 94  1/1/2015  19:22:00  37.714951 -122.442500           20
# 95  1/1/2015  19:27:00  37.763640 -122.416281           21
# 96  1/1/2015  19:29:00  37.714688 -122.447335           20
# 97  1/1/2015  19:30:00  37.784034 -122.454638           36
#
#               subject_race subject_sex  arrest_made  warning_issued   outcome
# 0                    black        male        False            True   warning
# 1                 hispanic      female        False            True   warning
# 2                    white        male        False           False  citation
# 3                    white        male        False           False  citation
# 4                    white        male        False            True   warning
# ..                     ...         ...          ...             ...       ...
# 93                   black      female        False           False  citation
# 94                hispanic      female        False           False  citation
# 95                   black        male        False            True   warning
# 96  asian/pacific islander      female        False            True   warning
# 97  asian/pacific islander      female        False           False  citation
#
# [98 rows x 10 columns]

# %%
#Removed rows where lat/long were NA. This removed 91 rows.

df2 = df1.dropna()

df2.head(-1)
# Out:
#         date      time        lat         lng  subject_age  \
# 0   1/1/2015   1:00:00  37.736362 -122.390097           23
# 1   1/1/2015   1:00:00  37.742207 -122.422097           30
# 2   1/1/2015   1:00:00  37.745603 -122.419898           35
# 3   1/1/2015   1:00:00  37.782485 -122.424125           44
# 4   1/1/2015   1:00:00  37.742822 -122.481078           60
# ..       ...       ...        ...         ...          ...
# 93  1/1/2015  19:20:00  37.780474 -122.475113           21
# 94  1/1/2015  19:22:00  37.714951 -122.442500           20
# 95  1/1/2015  19:27:00  37.763640 -122.416281           21
# 96  1/1/2015  19:29:00  37.714688 -122.447335           20
# 97  1/1/2015  19:30:00  37.784034 -122.454638           36
#
#               subject_race subject_sex  arrest_made  warning_issued   outcome
# 0                    black        male        False            True   warning
# 1                 hispanic      female        False            True   warning
# 2                    white        male        False           False  citation
# 3                    white        male        False           False  citation
# 4                    white        male        False            True   warning
# ..                     ...         ...          ...             ...       ...
# 93                   black      female        False           False  citation
# 94                hispanic      female        False           False  citation
# 95                   black        male        False            True   warning
# 96  asian/pacific islander      female        False            True   warning
# 97  asian/pacific islander      female        False           False  citation
#
# [98 rows x 10 columns]

# %%
df2.dtypes
# Out:
# date               object
# time               object
# lat               float64
# lng               float64
# subject_age         int64
# subject_race       object
# subject_sex        object
# arrest_made          bool
# warning_issued       bool
# outcome            object
# dtype: object

# %%
# Export dataframe to csv

# df2.to_csv('cleaned_version.csv',index=False)

# %%
# Export Data frame to mongodb

import pymongo

conn = 'mongodb://localhost:27017'

client = pymongo.MongoClient(conn)

db = client.test_db_2

collection = db.stops

db.collection.insert_many(df2.to_dict("records"))

# %%
# Loop through created mongodb to ensure creation of database .

police_stops = db.collection.find()
for stop in police_stops:
    print(stop)
# Out:
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66947'), 'date': '1/1/2015', 'time': '1:00:00', 'lat': 37.7363625, 'lng': -122.3900969, 'subject_age': 23, 'subject_race': 'black', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66948'), 'date': '1/1/2015', 'time': '1:00:00', 'lat': 37.7422074, 'lng': -122.42209720000001, 'subject_age': 30, 'subject_race': 'hispanic', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66949'), 'date': '1/1/2015', 'time': '1:00:00', 'lat': 37.745603499999994, 'lng': -122.4198975, 'subject_age': 35, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6694a'), 'date': '1/1/2015', 'time': '1:00:00', 'lat': 37.7824854, 'lng': -122.4241254, 'subject_age': 44, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6694b'), 'date': '1/1/2015', 'time': '1:00:00', 'lat': 37.742821899999996, 'lng': -122.48107759999998, 'subject_age': 60, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6694c'), 'date': '1/1/2015', 'time': '10:46:00', 'lat': 37.7393217, 'lng': -122.41828259999998, 'subject_age': 45, 'subject_race': 'white', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6694d'), 'date': '1/1/2015', 'time': '11:08:00', 'lat': 37.78280170000001, 'lng': -122.4676437, 'subject_age': 59, 'subject_race': 'asian/pacific islander', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6694e'), 'date': '1/1/2015', 'time': '11:44:00', 'lat': 37.7827489, 'lng': -122.46872340000002, 'subject_age': 38, 'subject_race': 'asian/pacific islander', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6694f'), 'date': '1/1/2015', 'time': '11:45:00', 'lat': 37.7427239, 'lng': -122.48321990000001, 'subject_age': 25, 'subject_race': 'asian/pacific islander', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66950'), 'date': '1/1/2015', 'time': '1:15:00', 'lat': 37.7755454, 'lng': -122.41403290000001, 'subject_age': 41, 'subject_race': 'other', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66951'), 'date': '1/1/2015', 'time': '11:53:00', 'lat': 37.7863203, 'lng': -122.4089512, 'subject_age': 30, 'subject_race': 'black', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c
 'subject_race': 'hispanic', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66996'), 'date': '1/1/2015', 'time': '18:30:00', 'lat': 37.787725, 'lng': -122.452758, 'subject_age': 35, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66997'), 'date': '1/1/2015', 'time': '18:31:00', 'lat': 37.7655641, 'lng': -122.4114895, 'subject_age': 41, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66998'), 'date': '1/1/2015', 'time': '18:35:00', 'lat': 37.7844912, 'lng': -122.45015349999998, 'subject_age': 58, 'subject_race': 'other', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c66999'), 'date': '1/1/2015', 'time': '18:40:00', 'lat': 37.7847402, 'lng': -122.4091521, 'subject_age': 31, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6699a'), 'date': '1/1/2015', 'time': '18:45:00', 'lat': 37.7634446, 'lng': -122.4195422, 'subject_age': 30, 'subject_race': 'black', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6699b'), 'date': '1/1/2015', 'time': '18:47:00', 'lat': 37.729767200000005, 'lng': -122.4333479, 'subject_age': 40, 'subject_race': 'hispanic', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6699c'), 'date': '1/1/2015', 'time': '18:50:00', 'lat': 37.786296899999996, 'lng': -122.47327949999999, 'subject_age': 42, 'subject_race': 'asian/pacific islander', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6699d'), 'date': '1/1/2015', 'time': '18:50:00', 'lat': 37.7840343, 'lng': -122.45463829999998, 'subject_age': 70, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6699e'), 'date': '1/1/2015', 'time': '18:57:00', 'lat': 37.8008993, 'lng': -122.41099640000002, 'subject_age': 50, 'subject_race': 'other', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c6699f'), 'date': '1/1/2015', 'time': '18:59:00', 'lat': 37.755444700000005, 'lng': -122.41877609999999, 'subject_age': 22, 'subject_race': 'black', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a0'), 'date': '1/1/2015', 'time': '19:00:00', 'lat': 37.781295, 'lng': -122.4600242, 'subject_age': 36, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a1'), 'date': '1/1/2015', 'time': '19:02:00', 'lat': 37.7830457, 'lng': -122.46229469999999, 'subject_age': 79, 'subject_race': 'asian/pacific islander', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a2'), 'date': '1/1/2015', 'time': '19:04:00', 'lat': 37.786541799999995, 'lng': -122.4679196, 'subject_age': 55, 'subject_race': 'white', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a3'), 'date': '1/1/2015', 'time': '19:19:00', 'lat': 37.7149511, 'lng': -122.44250009999999, 'subject_age': 19, 'subject_race': 'hispanic', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a4'), 'date': '1/1/2015', 'time': '19:20:00', 'lat': 37.780473799999996, 'lng': -122.4751129, 'subject_age': 21, 'subject_race': 'black', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a5'), 'date': '1/1/2015', 'time': '19:22:00', 'lat': 37.7149511, 'lng': -122.44250009999999, 'subject_age': 20, 'subject_race': 'hispanic', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a6'), 'date': '1/1/2015', 'time': '19:27:00', 'lat': 37.7636398, 'lng': -122.4162808, 'subject_age': 21, 'subject_race': 'black', 'subject_sex': 'male', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a7'), 'date': '1/1/2015', 'time': '19:29:00', 'lat': 37.714688200000005, 'lng': -122.44733500000001, 'subject_age': 20, 'subject_race': 'asian/pacific islander', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a8'), 'date': '1/1/2015', 'time': '19:30:00', 'lat': 37.7840343, 'lng': -122.45463829999998, 'subject_age': 36, 'subject_race': 'asian/pacific islander', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': False, 'outcome': 'citation'}
# {'_id': ObjectId('5ee5a47482ecdfdcc2c669a9'), 'date': '1/1/2015', 'time': '19:30:00', 'lat': 37.7627716, 'lng': -122.41965490000001, 'subject_age': 50, 'subject_race': 'black', 'subject_sex': 'female', 'arrest_made': False, 'warning_issued': True, 'outcome': 'warning'}
